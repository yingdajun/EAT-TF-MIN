# %%
# 使用深度学习的优化器、损失函数、评估指标、回调函数

# %%
import sklearn
# 分别用于取结构数据下，多分类、二分类、回归的操作
from sklearn.datasets import load_iris,load_breast_cancer,load_boston
from sklearn.model_selection import train_test_split

# %%
# 导入深度学习库
import tensorflow as tf
from tensorflow.keras import optimizers,losses,metrics,callbacks
from tensorflow.keras.utils import to_categorical

X_iris,y_iris=load_iris(return_X_y=True)

x_train_iris,x_test_iris,y_train_iris,y_test_iris=train_test_split(
    X_iris,y_iris,random_state=22,test_size=0.1)

y_train_iris_change=to_categorical(y_train_iris,3)
y_test_iris_change=to_categorical(y_test_iris,3)

# 由于这是一个多分类问题，所以取出来对应的损失函数与衡量标准

#如果loss在100个epoch后没有提升，学习率减半。
lr_callback = ReduceLROnPlateau(monitor="accuracy",factor = 0.5, patience = 100)
#当loss在200个epoch后没有提升，则提前终止训练。
stop_callback = EarlyStopping(monitor = "accuracy", patience= 200)
callbacks_list = [lr_callback,stop_callback]

from tensorflow.keras.metrics import Accuracy,AUC,CategoricalAccuracy

from tensorflow.keras.optimizers import Adam,Adagrad,Adadelta,Nadam,RMSprop,SGD

from tensorflow.keras.losses import CategoricalCrossentropy,CosineSimilarity

from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# 回调函数函数实体化

# 损失函数实体化

caloss=CategoricalAccuracy()
csloss=CosineSimilarity()

# 评估标准实体化

acc=Accuracy()
auc=AUC()
cacc=CategoricalAccuracy()

# 优化器实体化

from tensorflow.keras.optimizers import Adam,Adagrad,Adadelta,Nadam,RMSprop,SGD
adam=Adam()
adagrad=Adagrad()
adadelta=Adadelta()
nadam=Nadam()
rms=RMSprop()
sgd=SGD()

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

model=Sequential()
model.add(Dense(20,activation='relu',input_shape=(4,)))
model.add(Dense(10,activation='relu'))
model.add(Dense(3,activation='softmax'))

model.summary()

# %%
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['Accuracy'])

# %%
# 第一次犯错应该是这个s损失函数的问题

# %%
model.fit(x_train_iris,y_train_iris_change,batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 2ms/step - loss: 2.3227 - accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 0s 2ms/step - loss: 2.1120 - accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.9163 - accuracy: 0.0000e+00
# Epoch 4/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.7572 - accuracy: 0.0000e+00
# Epoch 5/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.6239 - accuracy: 0.0000e+00
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.5125 - accuracy: 0.0000e+00
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.4226 - accuracy: 0.0000e+00
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.3529 - accuracy: 0.0000e+00
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.2814 - accuracy: 0.0000e+00
# Epoch 10/100
# ...

# %%
model.compile(optimizer=adam,loss='cosine_similarity',metrics=['Accuracy'])
model.fit(x_train_iris,y_train_iris_change,batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 2ms/step - loss: -0.9376 - accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9386 - accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9397 - accuracy: 0.0000e+00
# Epoch 4/100
# 5/5 [==============================] - 0s 4ms/step - loss: -0.9403 - accuracy: 0.0000e+00
# Epoch 5/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9409 - accuracy: 0.0000e+00
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9414 - accuracy: 0.0000e+00
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9420 - accuracy: 0.0000e+00
# Epoch 8/100
# 5/5 [==============================] - 0s 4ms/step - loss: -0.9423 - accuracy: 0.0000e+00
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9422 - accuracy: 0.0000e+00
# Epoch 10/100
# ...

# %%
model.compile(optimizer=adam,loss='cosine_similarity',metrics=[acc,cacc,auc])
model.fit(x_train_iris,y_train_iris_change,batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 2ms/step - loss: -0.9669 - accuracy: 0.0000e+00 - categorical_accuracy: 0.0000e+00 - auc: 0.9990
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9673 - accuracy: 0.0000e+00 - categorical_accuracy: 0.0000e+00 - auc: 0.9989
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9675 - accuracy: 0.0000e+00 - categorical_accuracy: 0.0000e+00 - auc: 0.9989
# Epoch 4/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9670 - accuracy: 0.0000e+00 - categorical_accuracy: 0.0000e+00 - auc: 0.9988
# Epoch 5/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9681 - accuracy: 0.0000e+00 - categorical_accuracy: 0.0000e+00 - auc: 0.9989
# Epoch 6/100
# 5/5 [==============================] - 0s 3ms/step - loss: -0.9667 - accuracy: 0.0000e+00 - categorical_accuracy: 0.0000e+00 - auc: 0.9990
# Epoch 7/100
# ...

# %% [markdown]
# # 二分类模型

# %%
X_cancer,y_cancer= load_breast_cancer(return_X_y=True)

x_train_cancer,x_test_cancer,y_train_cancer,y_test_cancer=train_test_split(
    X_cancer,y_cancer,random_state=22,test_size=0.1)

x_test_cancer.shape

y_test_cancer.shape

# %%
# 导入深度学习库
import tensorflow as tf
from tensorflow.keras import optimizers,losses,metrics,callbacks
from tensorflow.keras.utils import to_categorical

# 由于这是一个二分类问题，所以取出来对应的损失函数与衡量标准

from tensorflow.keras.metrics import Accuracy,Precision,Recall,AUC

# 评估标准实体化

acc=Accuracy()
auc=AUC()
precision=Precision()
recall=Recall()

from tensorflow.keras.optimizers import Adam,Adagrad,Adadelta,Nadam,RMSprop,SGD

# 优化器实体化
adam=Adam()
adagrad=Adagrad()
adadelta=Adadelta()
nadam=Nadam()
rms=RMSprop()
sgd=SGD()


from tensorflow.keras.losses import BinaryCrossentropy,Hinge

# 损失函数实体化

bc=BinaryCrossentropy()
hinge=Hinge()


from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# 回调函数函数实体化

#如果loss在100个epoch后没有提升，学习率减半。
lr_callback = ReduceLROnPlateau(monitor="accuracy",factor = 0.5, patience = 100)
#当loss在200个epoch后没有提升，则提前终止训练。
stop_callback = EarlyStopping(monitor = "accuracy", patience= 200)
callbacks_list = [lr_callback,stop_callback]


from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

model=Sequential()
model.add(Dense(20,activation='relu',input_shape=(30,)))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_9 (Dense)              (None, 20)                620
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# ...
# Total params: 841
# Trainable params: 841
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=adam,loss=bc,metrics=[acc,auc,precision,recall])
model.fit(x_train_cancer,y_train_cancer,batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 3ms/step - loss: 7.5020 - accuracy: 0.0000e+00 - auc_3: 0.3415 - precision_2: 0.3407 - recall_2: 0.1420
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5419 - accuracy: 0.0000e+00 - auc_3: 0.5986 - precision_2: 0.7129 - recall_2: 0.6667
# Epoch 3/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6102 - accuracy: 0.0000e+00 - auc_3: 0.8442 - precision_2: 0.8511 - recall_2: 0.7407
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4980 - accuracy: 0.0000e+00 - auc_3: 0.8587 - precision_2: 0.8634 - recall_2: 0.9167
# Epoch 5/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.0000e+00 - auc_3: 0.9071 - precision_2: 0.9031 - recall_2: 0.8920
# Epoch 6/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.3506 - accuracy: 0.0000e+00 - auc_3: 0.9173 - precision_2: 0.8929 - recall_2: 0.9259
# Epoch 7/100
# ...

# %%
model.compile(optimizer=adam,loss=hinge,metrics=[acc,auc,precision,recall])
model.fit(x_train_cancer,y_train_cancer,batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4921 - accuracy: 0.0039 - auc_3: 0.9393 - precision_2: 0.8858 - recall_2: 0.9460
# Epoch 2/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4522 - accuracy: 0.0059 - auc_3: 0.9728 - precision_2: 0.9186 - recall_2: 0.9753
# Epoch 3/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4454 - accuracy: 0.0059 - auc_3: 0.9809 - precision_2: 0.9167 - recall_2: 0.9846
# Epoch 4/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4453 - accuracy: 0.0059 - auc_3: 0.9821 - precision_2: 0.9193 - recall_2: 0.9846
# Epoch 5/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.0059 - auc_3: 0.9730 - precision_2: 0.9117 - recall_2: 0.9877
# Epoch 6/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4540 - accuracy: 0.0059 - auc_3: 0.9761 - precision_2: 0.9256 - recall_2: 0.9599
# Epoch 7/100
# ...

# %% [markdown]
# # 回归操作

# %%
X_boston,y_boston= load_boston(return_X_y=True)

x_train_boston,x_test_boston,y_train_boston,y_test_boston=train_test_split(
    X_boston,y_boston,random_state=22,test_size=0.1)

print(x_test_boston.shape)

print(y_test_boston.shape)
# Out:
# (51, 13)
# (51,)

# %%
# 导入深度学习库
import tensorflow as tf
from tensorflow.keras import optimizers,losses,metrics,callbacks
from tensorflow.keras.utils import to_categorical

# 由于这是一个二分类问题，所以取出来对应的损失函数与衡量标准

from tensorflow.keras.metrics import MAE,MSE,MAPE,RootMeanSquaredError

# 评估标准实体化
# mse=MSE()

# mae=MAEE()

# mape=MAPE()

# root=RootMeanSquaredError()


from tensorflow.keras.optimizers import Adam,Adagrad,Adadelta,Nadam,RMSprop,SGD

# 优化器实体化
adam=Adam()
adagrad=Adagrad()
adadelta=Adadelta()
nadam=Nadam()
rms=RMSprop()
sgd=SGD()


from tensorflow.keras.losses import MSE

# 损失函数实体化

# mseloss=tensorflow.keras.losses.MSE()
# hinge=Hinge()


from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau

# 回调函数函数实体化

#如果loss在100个epoch后没有提升，学习率减半。
lr_callback = ReduceLROnPlateau(monitor="loss",factor = 0.5, patience = 100)
#当loss在200个epoch后没有提升，则提前终止训练。
stop_callback = EarlyStopping(monitor = "loss", patience= 200)
callbacks_list = [lr_callback,stop_callback]


from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
model=Sequential()
model.add(Dense(20,activation='relu',input_shape=(13,)))
model.add(Dense(10,activation='relu'))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_12 (Dense)             (None, 20)                280
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# ...
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=adam,loss='mse',metrics=['mse'])
model.fit(x_train_boston,y_train_boston,batch_size=32, epochs=200)
# Out:
# Epoch 1/200
# 15/15 [==============================] - 0s 2ms/step - loss: 23284.9707 - mse: 23284.9707
# Epoch 2/200
# 15/15 [==============================] - 0s 2ms/step - loss: 11196.2891 - mse: 11196.2891
# Epoch 3/200
# 15/15 [==============================] - 0s 2ms/step - loss: 4658.9136 - mse: 4658.9136
# Epoch 4/200
# 15/15 [==============================] - 0s 2ms/step - loss: 1766.4415 - mse: 1766.4415
# Epoch 5/200
# 15/15 [==============================] - 0s 2ms/step - loss: 671.6124 - mse: 671.6124
# Epoch 6/200
# 15/15 [==============================] - 0s 2ms/step - loss: 386.3474 - mse: 386.3474
# Epoch 7/200
# 15/15 [==============================] - 0s 2ms/step - loss: 308.9236 - mse: 308.9236
# Epoch 8/200
# 15/15 [==============================] - 0s 2ms/step - loss: 251.7998 - mse: 251.7998
# Epoch 9/200
# 15/15 [==============================] - 0s 2ms/step - loss: 204.6454 - mse: 204.6454
# Epoch 10/200
# ...
